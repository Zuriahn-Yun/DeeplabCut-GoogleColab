# %% [markdown]
# <a href="https://colab.research.google.com/github/Zuriahn-Yun/DeeplabCut-GoogleColab/blob/main/TrainDeepLabCuts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # First Change the Runtime to T4 Python 3

# %%
# !pip install --pre deeplabcut

# %%
# Mount the Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import zipfile
import os
path = "/content/drive/MyDrive/DeepLabCuts/test-testing-2025-09-24"

os.chdir(path)

# %%
import deeplabcut
config_path = os.path.join(path, 'config.yaml')
deeplabcut.create_training_dataset(config_path)
deeplabcut.train_network(config_path, shuffle=1, displayiters=100, saveiters=500)
# Out:
# Training with configuration:
# data:
#   bbox_margin: 20
#   colormode: RGB
#   inference:
#     normalize_images: True
#   train:
#     affine:
#       p: 0.5
#       rotation: 30
#       scaling: [0.5, 1.25]
#       translation: 0
#     crop_sampling:
#       width: 448
#       height: 448
#       max_shift: 0.1
#       method: hybrid
#     gaussian_noise: 12.75
#     motion_blur: True
#     normalize_images: True
# device: auto
# metadata:
#   project_path: C:\Users\zuria\Desktop\test-testing-2025-09-24
#   pose_config_path: C:\Users\zuria\Desktop\test-testing-2025-09-24\dlc-models-pytorch\iteration-0\testSep24-trainset95shuffle1\train\pytorch_config.yaml
#   bodyparts: ['head', 'body', 'tail']
#   unique_bodyparts: []
#   individuals: ['animal']
#   with_identity: None
# method: bu
# model:
#   backbone:
#     type: ResNet
#     model_name: resnet50_gn
#     output_stride: 16
#     freeze_bn_stats: False
#     freeze_bn_weights: False
#   backbone_output_channels: 2048
# ...
